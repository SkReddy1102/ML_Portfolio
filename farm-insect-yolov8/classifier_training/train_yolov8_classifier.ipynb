# %% [markdown]
# # YOLOv8 15-Class Farm Insect Classifier Training
#
# This notebook documents the training workflow for the 15-class YOLOv8 classification model used by the Streamlit app (`classifier_app/weights/insects.pt`). It is separate from the 3-class YOLO detection dataset included elsewhere in this repository.

# %% [markdown]
# Steps to follow
#
# 1.Change Runtime to GPU
#
# 2.Plug in google drive
#
# 3.Create a folder in drive and change directory
#
# 4.load datafrom roboflow
#
# 5.pip install ultralytics
#
# 6.Train the model using data

# %% [markdown]
# dataset link https://universe.roboflow.com/jitesh-m-d-ifwyd/farm-insects

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive

# %%
# !mkdir insects

# %%
cd insects

# %%
# !pwd

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_ROBOFLOW_API_KEY")
project = rf.workspace("jitesh-m-d-ifwyd").project("farm-insects")
dataset = project.version(1).download("folder")

# %%
# !pip install ultralytics

# %%
# !yolo classify train model='yolov8n-cls.pt' data=data epochs=50
